# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import re

# %%
data = pd.read_excel('./UCS_Satellite_Database_2-1-14.xls', 'Sheet1')
data = data.dropna(axis=1, how='all')
data.head()
# Out:
#                   Name of Satellite, Alternate Names  \
# 0                                           AAUSat-3
# 1      ABS-1 (LMI-1, Lockheed Martin-Intersputnik-1)
# 2           ABS-1A (Koreasat 2, Mugunghwa 2, ABS-1A)
# 3  ABS-2i (MBSat, Mobile Broadcasting Satellite, ...
# 4                    ABS-7 (Koreasat 3, Mugungwha 3)
#
#   Country of Operator/Owner               Operator/Owner       Users  \
# 0                   Denmark           Aalborg University       Civil
# 1             International  Asia Broadcasting Satellite  Commercial
# 2             International  Asia Broadcasting Satellite  Commercial
# 3                  PR China  Asia Broadcasting Satellite  Commercial
# 4             International     Asia Broadcast Satellite  Commercial
#
#                   Purpose Class of Orbit Type of Orbit  \
# 0  Technology Development            LEO           NaN
# 1          Communications            GEO           NaN
# 2          Communications            GEO           NaN
# ...

# %%
data.describe()
# Out:
#        Longitude of GEO (degrees)  Perigee (km)    Apogee (km)  Eccentricity  \
# count                 1157.000000   1166.000000    1166.000000   1167.000000
# mean                     4.598306  15507.611492   18385.071184      0.024601
# std                     55.272981  16640.114314   28491.018427      0.126071
# min                   -177.120000    186.000000     317.000000      0.000000
# 25%                      0.000000    681.000000     777.250000      0.000210
# 50%                      0.000000   1413.000000    1505.500000      0.000417
# 75%                      0.000000  35773.000000   35795.000000      0.001641
# max                    328.500000  37782.000000  470310.000000      0.972866
#
#        Inclination (degrees)  NORAD Number
# count            1164.000000   1167.000000
# mean               49.772440  32076.771208
# std                58.340293   5735.510698
# min                 0.000000   7530.000000
# 25%                 0.070000  26821.000000
# ...

# %%
data['Expected Lifetime'].value_counts()
# Out:
# 15 yrs.       226
# 5 yrs.        116
# 10 yrs.        86
# 8 yrs.         84
# 12 yrs.        64
# 3 yrs.         51
# 7 yrs.         43
# 2 yrs.         31
# 1 yr.          22
# 13 yrs.        20
# 4 yrs.         17
# 14 yrs.        11
# 2-3 yrs.        9
# 7.5 yrs.        9
# 5+ yrs.         7
# 5-7 yrs.        7
# 16 yrs.         5
# 6 yrs.          5
# 11 yrs.         5
# .5 yrs.         5
# 3-5 yrs.        4
# 18 yrs.         4
# 10-12 yrs.      4
# 7-10 yrs.       4
# 7-9 yrs.        3
# 9 yrs.          2
# 15+ yrs.        2
# 15  yrs.        2
# 15-18 yrs.      2
# 12.6 yrs.       2
# 2-4 yrs.        2
# .25 yrs.        2
# 1.5 yrs.        2
#  3 yrs.         1
# 2-10 yrs.       1
# 2+ yrs.         1
# 2.5 yrs.        1
# 7+ yrs.         1
# 12.2 yrs.       1
# 30+ yrs.        1
# <1 yr.          1
# 12 hrs.         1
# .25-1 yr.       1
# 5-8 yrs.        1
# 7.25 yrs.       1
# 10-15 yrs.      1
# 14yrs.          1
# 17 yrs.         1
# 14.5 yrs.       1
# 11.5 yrs.       1
# ...

# %%
def parse_lifetime(e_lifetime):
